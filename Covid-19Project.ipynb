# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer

# %%
df=pd.read_csv("C:/Users/shivani.mathur01/Desktop/Work/python/Chapter1/covid_19_india.csv")
df
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 14685  14686  2021-05-08  8:00 AM            Telangana
# 14686  14687  2021-05-08  8:00 AM              Tripura
# 14687  14688  2021-05-08  8:00 AM          Uttarakhand
# 14688  14689  2021-05-08  8:00 AM        Uttar Pradesh
# 14689  14690  2021-05-08  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
imputer=SimpleImputer(strategy='constant')
df2=pd.DataFrame(imputer.fit_transform(df),columns=df.columns)

# %%
df3=df2.groupby(['State/UnionTerritory','Date'])[['State/UnionTerritory','Date','Cured','Confirmed','Deaths']].sum().reset_index()

# %%
df3.head(20)
# Out:
#            State/UnionTerritory        Date  Cured  Confirmed  Deaths
# 0   Andaman and Nicobar Islands  2020-03-26      0          1       0
# 1   Andaman and Nicobar Islands  2020-03-27      0          1       0
# 2   Andaman and Nicobar Islands  2020-03-28      0          6       0
# 3   Andaman and Nicobar Islands  2020-03-29      0          9       0
# 4   Andaman and Nicobar Islands  2020-03-30      0          9       0
# 5   Andaman and Nicobar Islands  2020-03-31      0         10       0
# 6   Andaman and Nicobar Islands  2020-04-01      0         10       0
# 7   Andaman and Nicobar Islands  2020-04-02      0         10       0
# 8   Andaman and Nicobar Islands  2020-04-03      0         10       0
# 9   Andaman and Nicobar Islands  2020-04-04      0         10       0
# 10  Andaman and Nicobar Islands  2020-04-05      0         10       0
# 11  Andaman and Nicobar Islands  2020-04-06      0         10       0
# ...

# %%
states=df3['State/UnionTerritory'].unique()
len(states)
# Out:
# 40

# %%
for i in range(0,len(states)):
    C=df3[df3['State/UnionTerritory']==states[i]].reset_index()
    plt.scatter(np.arange(0,len(C)),C['Confirmed'],color='b',label='Confirmed')
    plt.scatter(np.arange(0,len(C)),C['Cured'],color='g',label='Cured')
    plt.scatter(np.arange(0,len(C)),C['Deaths'],color='r',label='Deaths')
    plt.title(states[i])
    plt.xlabel('Days since first patient')
    plt.ylabel('No. of Cases')
    plt.legend()
    plt.show()

# %%
df5=df2.groupby(['Date'])[[Confirmed','Cured','Deaths']].sum().reset_index()
df5
# Out:
#   File "<ipython-input-26-3f36d8e81eda>", line 1
#     df5=df2.groupby(['Date'])[['Date',Confirmed','Cured','Deaths']].sum().reset_index()
#                                                  ^
# SyntaxError: invalid syntax

# %%
K=df5
plt.scatter(np.arange(0,len(K)),K['Confirmed'],color='b',label='Confirmed')
plt.scatter(np.arange(0,len(K)),K['Cured'],color='g',label='Cured')
plt.scatter(np.arange(0,len(K)),K['Deaths'],color='r',label='Deaths')
plt.title('India')
plt.xlabel('Days since first patient')
plt.ylabel('No. of Cases')
plt.legend()
plt.show()
